# %%
from utils import *

import os

import torch
import torch.nn as nn
import torch.utils.data
import torch.nn.functional as F
import torch.optim as optim
from torch.optim import lr_scheduler

import pandas as pd
import numpy as np

from sklearn import preprocessing
from sklearn.model_selection import train_test_split

# %%
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

# %%
# Misc
LOG_DIR = './log_pt/'
MODEL_ID = 'storkes_plain'

# Training Parameters
learning_rate = 0.001
num_epochs = 200
batch_size = 256
display_step = 10

# Network Parameters
num_classes = 5
keep_rate = 1

repeat_size = 82
crop_size = 78

if not os.path.isdir(LOG_DIR):
    os.makedirs(LOG_DIR)

# %%
raw = pd.read_csv('./storks_obs_train.csv', header=None)

# %%
mean = np.array([0. for i in  range(3)])
X = []
Y = []

for i in range(len(raw)):
    
    row = np.array(raw.loc[i][~raw.loc[i].isnull()])
    data = row[0:-1].astype(float)
    label = row[-1]
    
    x_axis = data[0::3]
    y_axis = data[1::3]
    z_axis = data[2::3]
    
    x_axis = repeat_crop_data (x_axis, repeat_size)
    y_axis = repeat_crop_data (y_axis, repeat_size)
    z_axis = repeat_crop_data (z_axis, repeat_size)
    
    mean[0] += x_axis.mean()
    mean[1] += y_axis.mean()
    mean[2] += z_axis.mean()
    
    X.append(np.stack((x_axis, y_axis, z_axis)))
    Y.append(label)

mean = mean/len(raw)
    
X = np.array(X).transpose((0, 2, 1))
Y = np.array(Y)
label_names = np.unique(Y)

le = preprocessing.LabelEncoder()
le.fit(np.unique(Y))
Y = le.transform(Y)

# %%
train_x, test_x, train_y, test_y = train_test_split(X, Y, test_size=0.1)

# %%
class acc_dataset_augment (torch.utils.data.Dataset):
    
    def __init__ (self, X, Y, mean, input_size, crop_size):
        super().__init__()
        self.X = X
        self.Y = Y.astype(np.float)
        self.mean = mean
        self.input_size = input_size
        self.crop_size = crop_size
        
    def __len__ (self):
        return len(self.X)
    
    def __getitem__ (self, idx):
        
        x = self.X[idx]
        y = self.Y[idx]
        
        x = (x - self.mean).transpose(1, 0)
        
        start_idx = np.random.randint(self.input_size - self.crop_size, size=1).item()
        
        x_axis = x[0, start_idx:start_idx+self.crop_size]
        y_axis = x[1, start_idx:start_idx+self.crop_size]
        z_axis = x[2, start_idx:start_idx+self.crop_size]
        
        x = np.stack((x_axis, y_axis, z_axis))
            
        return torch.tensor(x), torch.tensor(y).type(torch.LongTensor)

# %%
train_set = acc_dataset_augment(train_x, train_y, mean, input_size=repeat_size, crop_size=crop_size)
train_loader = torch.utils.data.DataLoader(train_set, batch_size=batch_size, shuffle=True, num_workers=2)

test_set = acc_dataset_augment(test_x, test_y, mean, input_size=repeat_size, crop_size=crop_size)
test_loader = torch.utils.data.DataLoader(test_set, batch_size=batch_size, shuffle=True, num_workers=2)

# %%
class MyNet (nn.Module):
    
    def __init__ (self, num_classes, input_dim, drop_rate):
        super().__init__()
        
        self.input_dim = input_dim
        
        self.conv1 = nn.Conv1d(in_channels=3, out_channels=32, kernel_size=3, padding=1)
        self.conv2 = nn.Conv1d(in_channels=32, out_channels=64, kernel_size=3, padding=1)
        self.fc3 = nn.Linear(self.input_dim*64, 1024)
        self.drop = nn.Dropout(p=drop_rate)
        self.fc4 = nn.Linear(1024, num_classes)
        
    def forward(self, x):
        x = F.relu(self.conv1(x))
        x = F.relu(self.conv2(x))

        #self.pretrained_resnet.avgpool(x)
        x = x.view(-1, self.input_dim*64)
        
        x = F.relu(self.fc3(x))
        x = self.drop(x)
        x = self.fc4(x)

        return x

# %%
net = MyNet(num_classes=num_classes, input_dim=crop_size, drop_rate=0.3).double()

net.to(device)
# Out:
# MyNet(
#   (conv1): Conv1d(3, 32, kernel_size=(3,), stride=(1,), padding=(1,))
#   (conv2): Conv1d(32, 64, kernel_size=(3,), stride=(1,), padding=(1,))
#   (fc3): Linear(in_features=4992, out_features=1024, bias=True)
#   (drop): Dropout(p=0.3)
#   (fc4): Linear(in_features=1024, out_features=5, bias=True)
# )

# %%
# Loss function
loss_function = nn.CrossEntropyLoss().double()

# Optimizer
optimizer = optim.Adam(net.parameters(), lr=learning_rate)

# Decay LR by a factor of 0.1 every 30 epochs
exp_lr_scheduler = lr_scheduler.StepLR(optimizer, step_size=20, gamma=0.1)

# %%
step = 0

net.train()

for epoch in range(num_epochs):
    
    exp_lr_scheduler.step()
    
    for data in train_loader:
        
        x, y = data
        
        x, y = x.to(device), y.to(device)
        
        optimizer.zero_grad()
        
        logits = net(x)
        
        loss = loss_function(logits, y)
        
        loss.backward()
        
        optimizer.step()
        
        step += 1
        
        _, preds = torch.max(logits, 1)
        
        correct = (preds == y).sum().item()
        
        accuracy = correct/len(x)
        
        if step % display_step == 0:
            print('Epoch: %d, Step: %d, Minibatch loss: %.3f, Minibatch accuracy: %.3f' % 
                  (epoch, step, loss, accuracy))
            
print('Final, Step: %d, Minibatch loss: %.3f, Minibatch accuracy: %.3f' % 
                  (step, loss, accuracy))
# Out:
# Epoch: 1, Step: 10, Minibatch loss: 0.841, Minibatch accuracy: 0.730
# Epoch: 2, Step: 20, Minibatch loss: 0.657, Minibatch accuracy: 0.801
# Epoch: 4, Step: 30, Minibatch loss: 0.579, Minibatch accuracy: 0.809
# Epoch: 5, Step: 40, Minibatch loss: 0.452, Minibatch accuracy: 0.855
# Epoch: 7, Step: 50, Minibatch loss: 0.430, Minibatch accuracy: 0.863
# Epoch: 8, Step: 60, Minibatch loss: 0.360, Minibatch accuracy: 0.883
# Epoch: 9, Step: 70, Minibatch loss: 0.237, Minibatch accuracy: 0.914
# Epoch: 11, Step: 80, Minibatch loss: 0.209, Minibatch accuracy: 0.941
# Epoch: 12, Step: 90, Minibatch loss: 0.259, Minibatch accuracy: 0.930
# Epoch: 14, Step: 100, Minibatch loss: 0.186, Minibatch accuracy: 0.945
# Epoch: 15, Step: 110, Minibatch loss: 0.263, Minibatch accuracy: 0.910
# Epoch: 17, Step: 120, Minibatch loss: 0.241, Minibatch accuracy: 0.926
# Epoch: 18, Step: 130, Minibatch loss: 0.195, Minibatch accuracy: 0.949
# Epoch: 19, Step: 140, Minibatch loss: 0.378, Minibatch accuracy: 0.914
# Epoch: 21, Step: 150, Minibatch loss: 0.247, Minibatch accuracy: 0.930
# Epoch: 22, Step: 160, Minibatch loss: 0.230, Minibatch accuracy: 0.938
# Epoch: 24, Step: 170, Minibatch loss: 0.246, Minibatch accuracy: 0.930
# Epoch: 25, Step: 180, Minibatch loss: 0.164, Minibatch accuracy: 0.965
# Epoch: 27, Step: 190, Minibatch loss: 0.182, Minibatch accuracy: 0.945
# Epoch: 28, Step: 200, Minibatch loss: 0.217, Minibatch accuracy: 0.938
# Epoch: 29, Step: 210, Minibatch loss: 0.092, Minibatch accuracy: 0.971
# Epoch: 31, Step: 220, Minibatch loss: 0.156, Minibatch accuracy: 0.961
# Epoch: 32, Step: 230, Minibatch loss: 0.217, Minibatch accuracy: 0.938
# Epoch: 34, Step: 240, Minibatch loss: 0.180, Minibatch accuracy: 0.945
# Epoch: 35, Step: 250, Minibatch loss: 0.207, Minibatch accuracy: 0.934
# Epoch: 37, Step: 260, Minibatch loss: 0.202, Minibatch accuracy: 0.941
# Epoch: 38, Step: 270, Minibatch loss: 0.147, Minibatch accuracy: 0.957
# Epoch: 39, Step: 280, Minibatch loss: 0.223, Minibatch accuracy: 0.943
# Epoch: 41, Step: 290, Minibatch loss: 0.188, Minibatch accuracy: 0.945
# Epoch: 42, Step: 300, Minibatch loss: 0.204, Minibatch accuracy: 0.934
# Epoch: 44, Step: 310, Minibatch loss: 0.220, Minibatch accuracy: 0.945
# Epoch: 45, Step: 320, Minibatch loss: 0.200, Minibatch accuracy: 0.941
# Epoch: 47, Step: 330, Minibatch loss: 0.158, Minibatch accuracy: 0.953
# Epoch: 48, Step: 340, Minibatch loss: 0.183, Minibatch accuracy: 0.957
# Epoch: 49, Step: 350, Minibatch loss: 0.238, Minibatch accuracy: 0.943
# Epoch: 51, Step: 360, Minibatch loss: 0.189, Minibatch accuracy: 0.941
# Epoch: 52, Step: 370, Minibatch loss: 0.182, Minibatch accuracy: 0.953
# Epoch: 54, Step: 380, Minibatch loss: 0.206, Minibatch accuracy: 0.926
# Epoch: 55, Step: 390, Minibatch loss: 0.136, Minibatch accuracy: 0.961
# Epoch: 57, Step: 400, Minibatch loss: 0.150, Minibatch accuracy: 0.957
# Epoch: 58, Step: 410, Minibatch loss: 0.204, Minibatch accuracy: 0.934
# Epoch: 59, Step: 420, Minibatch loss: 0.083, Minibatch accuracy: 1.000
# Epoch: 61, Step: 430, Minibatch loss: 0.135, Minibatch accuracy: 0.965
# Epoch: 62, Step: 440, Minibatch loss: 0.171, Minibatch accuracy: 0.941
# Epoch: 64, Step: 450, Minibatch loss: 0.165, Minibatch accuracy: 0.953
# Epoch: 65, Step: 460, Minibatch loss: 0.167, Minibatch accuracy: 0.953
# Epoch: 67, Step: 470, Minibatch loss: 0.159, Minibatch accuracy: 0.961
# Epoch: 68, Step: 480, Minibatch loss: 0.158, Minibatch accuracy: 0.969
# Epoch: 69, Step: 490, Minibatch loss: 0.213, Minibatch accuracy: 0.943
# Epoch: 71, Step: 500, Minibatch loss: 0.187, Minibatch accuracy: 0.938
# Epoch: 72, Step: 510, Minibatch loss: 0.158, Minibatch accuracy: 0.945
# Epoch: 74, Step: 520, Minibatch loss: 0.128, Minibatch accuracy: 0.969
# Epoch: 75, Step: 530, Minibatch loss: 0.141, Minibatch accuracy: 0.961
# Epoch: 77, Step: 540, Minibatch loss: 0.200, Minibatch accuracy: 0.945
# Epoch: 78, Step: 550, Minibatch loss: 0.137, Minibatch accuracy: 0.957
# Epoch: 79, Step: 560, Minibatch loss: 0.095, Minibatch accuracy: 0.971
# Epoch: 81, Step: 570, Minibatch loss: 0.208, Minibatch accuracy: 0.941
# Epoch: 82, Step: 580, Minibatch loss: 0.182, Minibatch accuracy: 0.957
# Epoch: 84, Step: 590, Minibatch loss: 0.230, Minibatch accuracy: 0.934
# Epoch: 85, Step: 600, Minibatch loss: 0.202, Minibatch accuracy: 0.934
# Epoch: 87, Step: 610, Minibatch loss: 0.178, Minibatch accuracy: 0.938
# Epoch: 88, Step: 620, Minibatch loss: 0.225, Minibatch accuracy: 0.945
# Epoch: 89, Step: 630, Minibatch loss: 0.267, Minibatch accuracy: 0.886
# Epoch: 91, Step: 640, Minibatch loss: 0.143, Minibatch accuracy: 0.953
# Epoch: 92, Step: 650, Minibatch loss: 0.149, Minibatch accuracy: 0.953
# Epoch: 94, Step: 660, Minibatch loss: 0.197, Minibatch accuracy: 0.926
# Epoch: 95, Step: 670, Minibatch loss: 0.213, Minibatch accuracy: 0.930
# Epoch: 97, Step: 680, Minibatch loss: 0.154, Minibatch accuracy: 0.957
# Epoch: 98, Step: 690, Minibatch loss: 0.159, Minibatch accuracy: 0.953
# Epoch: 99, Step: 700, Minibatch loss: 0.118, Minibatch accuracy: 1.000
# Epoch: 101, Step: 710, Minibatch loss: 0.141, Minibatch accuracy: 0.965
# Epoch: 102, Step: 720, Minibatch loss: 0.154, Minibatch accuracy: 0.949
# Epoch: 104, Step: 730, Minibatch loss: 0.217, Minibatch accuracy: 0.930
# Epoch: 105, Step: 740, Minibatch loss: 0.184, Minibatch accuracy: 0.934
# Epoch: 107, Step: 750, Minibatch loss: 0.144, Minibatch accuracy: 0.969
# Epoch: 108, Step: 760, Minibatch loss: 0.189, Minibatch accuracy: 0.930
# Epoch: 109, Step: 770, Minibatch loss: 0.130, Minibatch accuracy: 0.943
# Epoch: 111, Step: 780, Minibatch loss: 0.175, Minibatch accuracy: 0.945
# Epoch: 112, Step: 790, Minibatch loss: 0.192, Minibatch accuracy: 0.949
# Epoch: 114, Step: 800, Minibatch loss: 0.195, Minibatch accuracy: 0.938
# Epoch: 115, Step: 810, Minibatch loss: 0.172, Minibatch accuracy: 0.949
# Epoch: 117, Step: 820, Minibatch loss: 0.158, Minibatch accuracy: 0.945
# Epoch: 118, Step: 830, Minibatch loss: 0.175, Minibatch accuracy: 0.953
# Epoch: 119, Step: 840, Minibatch loss: 0.137, Minibatch accuracy: 0.971
# Epoch: 121, Step: 850, Minibatch loss: 0.215, Minibatch accuracy: 0.934
# Epoch: 122, Step: 860, Minibatch loss: 0.135, Minibatch accuracy: 0.953
# Epoch: 124, Step: 870, Minibatch loss: 0.179, Minibatch accuracy: 0.938
# Epoch: 125, Step: 880, Minibatch loss: 0.185, Minibatch accuracy: 0.949
# Epoch: 127, Step: 890, Minibatch loss: 0.238, Minibatch accuracy: 0.922
# Epoch: 128, Step: 900, Minibatch loss: 0.220, Minibatch accuracy: 0.934
# Epoch: 129, Step: 910, Minibatch loss: 0.301, Minibatch accuracy: 0.914
# Epoch: 131, Step: 920, Minibatch loss: 0.118, Minibatch accuracy: 0.973
# Epoch: 132, Step: 930, Minibatch loss: 0.183, Minibatch accuracy: 0.945
# Epoch: 134, Step: 940, Minibatch loss: 0.209, Minibatch accuracy: 0.922
# Epoch: 135, Step: 950, Minibatch loss: 0.208, Minibatch accuracy: 0.934
# Epoch: 137, Step: 960, Minibatch loss: 0.169, Minibatch accuracy: 0.953
# Epoch: 138, Step: 970, Minibatch loss: 0.178, Minibatch accuracy: 0.953
# Epoch: 139, Step: 980, Minibatch loss: 0.261, Minibatch accuracy: 0.914
# Epoch: 141, Step: 990, Minibatch loss: 0.163, Minibatch accuracy: 0.953
# Epoch: 142, Step: 1000, Minibatch loss: 0.160, Minibatch accuracy: 0.961
# Epoch: 144, Step: 1010, Minibatch loss: 0.128, Minibatch accuracy: 0.957
# Epoch: 145, Step: 1020, Minibatch loss: 0.144, Minibatch accuracy: 0.961
# Epoch: 147, Step: 1030, Minibatch loss: 0.163, Minibatch accuracy: 0.938
# Epoch: 148, Step: 1040, Minibatch loss: 0.235, Minibatch accuracy: 0.914
# Epoch: 149, Step: 1050, Minibatch loss: 0.193, Minibatch accuracy: 0.943
# Epoch: 151, Step: 1060, Minibatch loss: 0.185, Minibatch accuracy: 0.941
# Epoch: 152, Step: 1070, Minibatch loss: 0.115, Minibatch accuracy: 0.969
# Epoch: 154, Step: 1080, Minibatch loss: 0.116, Minibatch accuracy: 0.969
# Epoch: 155, Step: 1090, Minibatch loss: 0.154, Minibatch accuracy: 0.949
# Epoch: 157, Step: 1100, Minibatch loss: 0.199, Minibatch accuracy: 0.945
# Epoch: 158, Step: 1110, Minibatch loss: 0.147, Minibatch accuracy: 0.965
# Epoch: 159, Step: 1120, Minibatch loss: 0.186, Minibatch accuracy: 0.914
# Epoch: 161, Step: 1130, Minibatch loss: 0.177, Minibatch accuracy: 0.945
# Epoch: 162, Step: 1140, Minibatch loss: 0.142, Minibatch accuracy: 0.965
# Epoch: 164, Step: 1150, Minibatch loss: 0.153, Minibatch accuracy: 0.957
# Epoch: 165, Step: 1160, Minibatch loss: 0.197, Minibatch accuracy: 0.926
# Epoch: 167, Step: 1170, Minibatch loss: 0.133, Minibatch accuracy: 0.961
# Epoch: 168, Step: 1180, Minibatch loss: 0.119, Minibatch accuracy: 0.965
# Epoch: 169, Step: 1190, Minibatch loss: 0.135, Minibatch accuracy: 0.971
# Epoch: 171, Step: 1200, Minibatch loss: 0.185, Minibatch accuracy: 0.938
# Epoch: 172, Step: 1210, Minibatch loss: 0.153, Minibatch accuracy: 0.969
# Epoch: 174, Step: 1220, Minibatch loss: 0.127, Minibatch accuracy: 0.949
# Epoch: 175, Step: 1230, Minibatch loss: 0.146, Minibatch accuracy: 0.965
# Epoch: 177, Step: 1240, Minibatch loss: 0.168, Minibatch accuracy: 0.945
# Epoch: 178, Step: 1250, Minibatch loss: 0.199, Minibatch accuracy: 0.930
# Epoch: 179, Step: 1260, Minibatch loss: 0.060, Minibatch accuracy: 1.000
# Epoch: 181, Step: 1270, Minibatch loss: 0.138, Minibatch accuracy: 0.961
# Epoch: 182, Step: 1280, Minibatch loss: 0.150, Minibatch accuracy: 0.945
# Epoch: 184, Step: 1290, Minibatch loss: 0.212, Minibatch accuracy: 0.941
# Epoch: 185, Step: 1300, Minibatch loss: 0.188, Minibatch accuracy: 0.945
# Epoch: 187, Step: 1310, Minibatch loss: 0.173, Minibatch accuracy: 0.953
# Epoch: 188, Step: 1320, Minibatch loss: 0.173, Minibatch accuracy: 0.938
# Epoch: 189, Step: 1330, Minibatch loss: 0.101, Minibatch accuracy: 1.000
# Epoch: 191, Step: 1340, Minibatch loss: 0.135, Minibatch accuracy: 0.973
# Epoch: 192, Step: 1350, Minibatch loss: 0.173, Minibatch accuracy: 0.949
# Epoch: 194, Step: 1360, Minibatch loss: 0.211, Minibatch accuracy: 0.949
# Epoch: 195, Step: 1370, Minibatch loss: 0.148, Minibatch accuracy: 0.941
# Epoch: 197, Step: 1380, Minibatch loss: 0.135, Minibatch accuracy: 0.945
# Epoch: 198, Step: 1390, Minibatch loss: 0.153, Minibatch accuracy: 0.953
# Epoch: 199, Step: 1400, Minibatch loss: 0.128, Minibatch accuracy: 0.943
# Final, Step: 1400, Minibatch loss: 0.128, Minibatch accuracy: 0.943

# %%
net.eval()

test_correct = 0

with torch.no_grad():
    
    for data in test_loader:

        test_x, test_y = data
        
        test_x, test_y = test_x.to(device), test_y.to(device)

        test_logits = net(test_x)
        _, test_preds = torch.max(test_logits, 1)

        test_correct_batch = (test_preds == test_y).sum().item()

        test_correct += test_correct_batch

print('Test accuracy: %.3f' % (test_correct / len(test_set)))
# Out:
# Test accuracy: 0.914

# %%
torch.save(net.state_dict(), os.path.join(LOG_DIR, 'model_%s_checkpoint.pth.tar' % 'storks_plain_ep_100_step_20'))
